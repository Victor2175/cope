# %% [markdown]
# # This notebook aims at processing the data (redefine the dates)

# %%
import numpy as np
import matplotlib
import netCDF4 as netcdf

# %% [markdown]
# ## 1- Extract the metadata

# %%
import os

# Get the list of all files and directories
path = "/net/atmos/data/cmip6-ng/tos/ann/g025"
dir_list = os.listdir(path)

print("Files and directories in '", path, "' :")

dic_files = {}

list_model = []
list_forcing = []

for idx, file in enumerate(dir_list):

    file_split = file.split("_")
    
    # extract model names
    model_name = file_split[2]
    forcing = file_split[3]
    run_name = file_split[4]
    
    
    list_model.append(model_name)
    list_forcing.append(forcing)
    
model_names = list(set(list_model))
forcing_names = list(set(list_forcing))

# define names dictionary 
dic_model_forcing = {}

for idx,model in enumerate(model_names):
    print(idx, model)
    dic_model_forcing[model] = {}
    for forcing in forcing_names:
        dic_model_forcing[model][forcing] = {}
# Out:
# Files and directories in ' /net/atmos/data/cmip6-ng/tos/ann/g025 ' :
# 0 CESM2-FV2
# 1 NorESM2-MM
# 2 MRI-ESM2-0
# 3 MCM-UA-1-0
# 4 NorESM1-F
# 5 GISS-E2-1-G-CC
# 6 MPI-ESM1-2-HR
# 7 ACCESS-ESM1-5
# 8 CAS-ESM2-0
# 9 FIO-ESM-2-0
# 10 GISS-E3-G
# 11 E3SM-2-0-NARRM
# 12 KACE-1-0-G
# 13 SAM0-UNICON
# 14 ACCESS-CM2
# 15 NorCPM1
# 16 EC-Earth3-LR
# 17 TaiESM1
# 18 E3SM-1-1-ECA
# 19 GFDL-ESM4
# 20 MIROC-ES2L
# 21 CanESM5-1
# 22 HadGEM3-GC31-MM
# 23 CIESM
# 24 CNRM-ESM2-1
# 25 EC-Earth3-Veg
# 26 UKESM1-0-LL
# 27 UKESM1-1-LL
# 28 CNRM-CM6-1
# 29 INM-CM5-0
# 30 GISS-E2-1-G
# 31 KIOST-ESM
# 32 MIROC-ES2H
# 33 IPSL-CM5A2-INCA
# 34 ICON-ESM-LR
# 35 E3SM-2-0
# 36 FGOALS-g3
# 37 IPSL-CM6A-LR-INCA
# 38 BCC-CSM2-MR
# 39 CAMS-CSM1-0
# 40 HadGEM3-GC31-LL
# 41 EC-Earth3-AerChem
# 42 NorESM2-LM
# 43 EC-Earth3-Veg-LR
# 44 MPI-ESM-1-2-HAM
# 45 CMCC-CM2-SR5
# 46 IPSL-CM6A-LR
# 47 BCC-ESM1
# 48 CESM2-WACCM-FV2
# 49 CMCC-CM2-HR4
# 50 AWI-CM-1-1-MR
# 51 GISS-E2-2-H
# 52 CESM2-WACCM
# 53 GISS-E2-2-G
# 54 E3SM-1-0
# 55 GISS-E2-1-H
# 56 GFDL-CM4
# 57 NESM3
# 58 CMCC-ESM2
# 59 AWI-ESM-1-1-LR
# 60 INM-CM4-8
# 61 CNRM-CM6-1-HR
# 62 CanESM5-CanOE
# 63 CESM2
# 64 MPI-ESM1-2-LR
# 65 MIROC6
# 66 E3SM-1-1
# 67 FGOALS-f3-L
# 68 CanESM5
# 69 EC-Earth3
# 70 IITM-ESM

# %%
M = np.zeros((144,72))
for i in range(72):
    M[2*i,i] = 1/2
    M[2*i+1,i] = 1/2

# %%
U = np.random.rand(72,144)
print(np.mean(U[0,0:2]))
print(np.dot(U,M))
# Out:
# 0.5041531848640128
# [[0.50415318 0.83244125 0.26538955 ... 0.28313603 0.63134567 0.76045558]
#  [0.93093481 0.59294451 0.52581834 ... 0.36080528 0.6887384  0.49133394]
#  [0.64089404 0.44629855 0.7297673  ... 0.51201998 0.43541673 0.50667414]
#  ...
#  [0.18007497 0.33756892 0.32138285 ... 0.70694561 0.26053805 0.35306225]
#  [0.34286297 0.16449366 0.35708145 ... 0.67564644 0.16997748 0.26957164]
#  [0.6423668  0.16388931 0.59586199 ... 0.7869658  0.21915291 0.49949443]]

# %% [markdown]
# ## 2- Extract the data from each file (model, forcing, ensemble member)

# %%
for idx, file in enumerate(dir_list):

    file_split = file.split("_")

    # extract model names
    model = file_split[2]
    forcing = file_split[3]
    run_name = file_split[4]
    
    if model in list(dic_model_forcing.keys()):
          
        # read files in the directory
        file2read = netcdf.Dataset(path +'/'+ file,'r')
        

        # set variables
        time = np.array(file2read.variables['time'][:])
        longitude = np.array(file2read.variables['lon'][:])
        latitude = np.array(file2read.variables['lat'][:])
        tos = np.array(file2read.variables['tos'][:])
        
        
        if (forcing == 'historical'):
            print(file)
            print(time/365)
            
        if (forcing == 'ssp585'):
            print(file)
            print(time/365)
            
        # assign nans to non-sea values
        tos[tos>1e19] = np.nan
        idx_nans = np.argwhere(np.isnan(tos))

        # get the data
        dic_model_forcing[model][forcing][run_name]= tos
# Out:
# tos_ann_AWI-CM-1-1-MR_historical_r1i1p1f1_g025.nc
# tos_ann_AWI-CM-1-1-MR_historical_r2i1p1f1_g025.nc
# tos_ann_AWI-CM-1-1-MR_historical_r3i1p1f1_g025.nc
# tos_ann_AWI-CM-1-1-MR_historical_r4i1p1f1_g025.nc
# tos_ann_AWI-CM-1-1-MR_historical_r5i1p1f1_g025.nc
# tos_ann_BCC-CSM2-MR_historical_r1i1p1f1_g025.nc
# tos_ann_BCC-CSM2-MR_historical_r2i1p1f1_g025.nc
# tos_ann_BCC-CSM2-MR_historical_r3i1p1f1_g025.nc
# tos_ann_BCC-ESM1_historical_r1i1p1f1_g025.nc
# tos_ann_BCC-ESM1_historical_r2i1p1f1_g025.nc
# tos_ann_BCC-ESM1_historical_r3i1p1f1_g025.nc
# tos_ann_CAMS-CSM1-0_historical_r1i1p1f1_g025.nc
# tos_ann_CAMS-CSM1-0_historical_r2i1p1f1_g025.nc
# tos_ann_CAMS-CSM1-0_historical_r1i1p1f2_g025.nc
# tos_ann_CESM2-WACCM_historical_r1i1p1f1_g025.nc
# tos_ann_CESM2-WACCM_historical_r2i1p1f1_g025.nc
# tos_ann_CESM2-WACCM_historical_r3i1p1f1_g025.nc
# tos_ann_CESM2_historical_r10i1p1f1_g025.nc
# tos_ann_CESM2_historical_r11i1p1f1_g025.nc
# tos_ann_CESM2_historical_r1i1p1f1_g025.nc
# tos_ann_CESM2_historical_r2i1p1f1_g025.nc
# tos_ann_CESM2_historical_r3i1p1f1_g025.nc
# tos_ann_CESM2_historical_r4i1p1f1_g025.nc
# tos_ann_CESM2_historical_r5i1p1f1_g025.nc
# tos_ann_CESM2_historical_r6i1p1f1_g025.nc
# tos_ann_CESM2_historical_r7i1p1f1_g025.nc
# tos_ann_CESM2_historical_r8i1p1f1_g025.nc
# tos_ann_CESM2_historical_r9i1p1f1_g025.nc
# tos_ann_CNRM-CM6-1_historical_r10i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r1i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r2i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r3i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r4i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r5i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r6i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r7i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r8i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r9i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r11i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r12i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r13i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r14i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r15i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r16i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r17i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r18i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r19i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r20i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r21i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r22i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r23i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r24i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r25i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r26i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r27i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r28i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r29i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_historical_r30i1p1f2_g025.nc
# tos_ann_CNRM-ESM2-1_historical_r1i1p1f2_g025.nc
# tos_ann_CNRM-ESM2-1_historical_r2i1p1f2_g025.nc
# tos_ann_CNRM-ESM2-1_historical_r3i1p1f2_g025.nc
# tos_ann_CNRM-ESM2-1_historical_r4i1p1f2_g025.nc
# tos_ann_CNRM-ESM2-1_historical_r5i1p1f2_g025.nc
# tos_ann_CNRM-ESM2-1_historical_r7i1p1f2_g025.nc
# tos_ann_CNRM-ESM2-1_historical_r6i1p1f2_g025.nc
# tos_ann_CNRM-ESM2-1_historical_r8i1p1f2_g025.nc
# tos_ann_CNRM-ESM2-1_historical_r10i1p1f2_g025.nc
# tos_ann_CanESM5_historical_r10i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r10i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r11i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r12i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r13i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r14i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r15i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r16i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r17i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r18i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r19i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r1i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r1i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r20i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r21i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r22i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r23i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r24i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r25i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r2i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r2i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r3i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r3i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r4i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r4i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r5i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r5i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r6i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r6i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r7i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r7i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r8i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r8i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r9i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r9i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r16i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r13i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r14i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r23i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r18i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r11i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r24i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r25i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r22i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r21i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r20i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r19i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r15i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r17i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r12i1p2f1_g025.nc
# tos_ann_EC-Earth3-Veg_historical_r1i1p1f1_g025.nc
# tos_ann_EC-Earth3-Veg_historical_r4i1p1f1_g025.nc
# tos_ann_EC-Earth3-Veg_historical_r2i1p1f1_g025.nc
# tos_ann_EC-Earth3-Veg_historical_r3i1p1f1_g025.nc
# tos_ann_EC-Earth3_historical_r1i1p1f1_g025.nc
# tos_ann_EC-Earth3_historical_r22i1p1f1_g025.nc
# tos_ann_EC-Earth3_historical_r24i1p1f1_g025.nc
# tos_ann_EC-Earth3_historical_r21i1p1f1_g025.nc
# tos_ann_EC-Earth3_historical_r6i1p1f1_g025.nc
# tos_ann_EC-Earth3_historical_r9i1p1f1_g025.nc
# tos_ann_EC-Earth3_historical_r11i1p1f1_g025.nc
# tos_ann_EC-Earth3_historical_r13i1p1f1_g025.nc
# tos_ann_EC-Earth3_historical_r15i1p1f1_g025.nc
# tos_ann_EC-Earth3_historical_r4i1p1f1_g025.nc
# tos_ann_EC-Earth3_historical_r7i1p1f1_g025.nc
# tos_ann_EC-Earth3_historical_r19i1p1f1_g025.nc
# tos_ann_EC-Earth3_historical_r20i1p1f1_g025.nc
# tos_ann_EC-Earth3_historical_r12i1p1f1_g025.nc
# tos_ann_EC-Earth3_historical_r18i1p1f1_g025.nc
# tos_ann_EC-Earth3_historical_r16i1p1f1_g025.nc
# tos_ann_EC-Earth3_historical_r17i1p1f1_g025.nc
# tos_ann_EC-Earth3_historical_r14i1p1f1_g025.nc
# tos_ann_GFDL-CM4_historical_r1i1p1f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r10i1p1f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r1i1p1f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r2i1p1f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r3i1p1f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r4i1p1f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r5i1p1f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r6i1p1f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r7i1p1f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r8i1p1f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r9i1p1f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r1i1p1f2_g025.nc
# tos_ann_GISS-E2-1-G_historical_r3i1p1f2_g025.nc
# tos_ann_GISS-E2-1-G_historical_r2i1p1f2_g025.nc
# tos_ann_GISS-E2-1-G_historical_r4i1p1f2_g025.nc
# tos_ann_GISS-E2-1-G_historical_r5i1p1f2_g025.nc
# tos_ann_GISS-E2-1-G_historical_r6i1p1f2_g025.nc
# tos_ann_GISS-E2-1-G_historical_r7i1p1f2_g025.nc
# tos_ann_GISS-E2-1-G_historical_r8i1p1f2_g025.nc
# tos_ann_GISS-E2-1-G_historical_r102i1p1f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r10i1p1f2_g025.nc
# tos_ann_GISS-E2-1-G_historical_r9i1p1f2_g025.nc
# tos_ann_GISS-E2-1-G_historical_r101i1p1f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r6i1p3f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r1i1p3f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r3i1p3f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r4i1p3f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r5i1p3f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r2i1p3f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r9i1p3f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r8i1p3f1_g025.nc
# tos_ann_GISS-E2-1-H_historical_r10i1p1f1_g025.nc
# tos_ann_GISS-E2-1-H_historical_r1i1p1f1_g025.nc
# tos_ann_GISS-E2-1-H_historical_r2i1p1f1_g025.nc
# tos_ann_GISS-E2-1-H_historical_r3i1p1f1_g025.nc
# tos_ann_GISS-E2-1-H_historical_r4i1p1f1_g025.nc
# tos_ann_GISS-E2-1-H_historical_r5i1p1f1_g025.nc
# tos_ann_GISS-E2-1-H_historical_r6i1p1f1_g025.nc
# tos_ann_GISS-E2-1-H_historical_r7i1p1f1_g025.nc
# tos_ann_GISS-E2-1-H_historical_r8i1p1f1_g025.nc
# tos_ann_GISS-E2-1-H_historical_r9i1p1f1_g025.nc
# tos_ann_GISS-E2-1-H_historical_r1i1p1f2_g025.nc
# tos_ann_GISS-E2-1-H_historical_r2i1p3f1_g025.nc
# tos_ann_GISS-E2-1-H_historical_r1i1p3f1_g025.nc
# tos_ann_GISS-E2-1-H_historical_r3i1p3f1_g025.nc
# tos_ann_GISS-E2-1-H_historical_r4i1p3f1_g025.nc
# tos_ann_GISS-E2-1-H_historical_r5i1p3f1_g025.nc
# tos_ann_GISS-E2-1-H_historical_r2i1p1f2_g025.nc
# tos_ann_GISS-E2-1-H_historical_r3i1p1f2_g025.nc
# tos_ann_GISS-E2-1-H_historical_r5i1p1f2_g025.nc
# tos_ann_GISS-E2-1-H_historical_r4i1p1f2_g025.nc
# tos_ann_GISS-E2-1-H_historical_r1i1p5f1_g025.nc
# tos_ann_GISS-E2-1-H_historical_r2i1p5f1_g025.nc
# tos_ann_GISS-E2-1-H_historical_r3i1p5f1_g025.nc
# tos_ann_HadGEM3-GC31-LL_historical_r1i1p1f3_g025.nc
# tos_ann_HadGEM3-GC31-LL_historical_r2i1p1f3_g025.nc
# tos_ann_HadGEM3-GC31-LL_historical_r3i1p1f3_g025.nc
# tos_ann_HadGEM3-GC31-LL_historical_r4i1p1f3_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r10i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r11i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r12i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r13i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r14i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r15i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r16i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r17i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r18i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r19i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r1i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r20i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r21i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r22i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r23i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r24i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r25i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r26i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r27i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r28i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r29i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r2i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r30i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r31i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r3i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r4i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r5i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r6i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r7i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r8i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r9i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r32i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r10i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r1i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r2i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r3i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r4i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r5i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r6i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r7i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r8i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r9i1p1f1_g025.nc
# tos_ann_SAM0-UNICON_historical_r1i1p1f1_g025.nc
# tos_ann_UKESM1-0-LL_historical_r1i1p1f2_g025.nc
# tos_ann_UKESM1-0-LL_historical_r2i1p1f2_g025.nc
# tos_ann_UKESM1-0-LL_historical_r3i1p1f2_g025.nc
# tos_ann_UKESM1-0-LL_historical_r4i1p1f2_g025.nc
# tos_ann_UKESM1-0-LL_historical_r6i1p1f3_g025.nc
# tos_ann_UKESM1-0-LL_historical_r8i1p1f2_g025.nc
# tos_ann_UKESM1-0-LL_historical_r9i1p1f2_g025.nc
# tos_ann_UKESM1-0-LL_historical_r17i1p1f2_g025.nc
# tos_ann_UKESM1-0-LL_historical_r18i1p1f2_g025.nc
# tos_ann_UKESM1-0-LL_historical_r19i1p1f2_g025.nc
# tos_ann_UKESM1-0-LL_historical_r10i1p1f2_g025.nc
# tos_ann_UKESM1-0-LL_historical_r5i1p1f3_g025.nc
# tos_ann_UKESM1-0-LL_historical_r7i1p1f3_g025.nc
# tos_ann_UKESM1-0-LL_historical_r11i1p1f2_g025.nc
# tos_ann_UKESM1-0-LL_historical_r12i1p1f2_g025.nc
# tos_ann_UKESM1-0-LL_historical_r16i1p1f2_g025.nc
# tos_ann_NESM3_historical_r1i1p1f1_g025.nc
# tos_ann_NESM3_historical_r3i1p1f1_g025.nc
# tos_ann_NESM3_historical_r4i1p1f1_g025.nc
# tos_ann_NESM3_historical_r2i1p1f1_g025.nc
# tos_ann_NESM3_historical_r5i1p1f1_g025.nc
# tos_ann_MIROC-ES2L_historical_r1i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r2i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r3i1p1f2_g025.nc
# tos_ann_GFDL-ESM4_historical_r1i1p1f1_g025.nc
# tos_ann_E3SM-1-0_historical_r1i1p1f1_g025.nc
# tos_ann_E3SM-1-0_historical_r2i1p1f1_g025.nc
# tos_ann_E3SM-1-0_historical_r3i1p1f1_g025.nc
# tos_ann_E3SM-1-0_historical_r4i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_historical_r1i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_historical_r2i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_historical_r4i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_historical_r3i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_historical_r5i1p1f1_g025.nc
# tos_ann_GISS-E2-1-G-CC_historical_r1i1p1f1_g025.nc
# tos_ann_MCM-UA-1-0_historical_r1i1p1f1_g025.nc
# tos_ann_MCM-UA-1-0_historical_r1i1p1f2_g025.nc
# tos_ann_NorESM2-LM_historical_r1i1p1f1_g025.nc
# tos_ann_NorESM2-LM_historical_r2i1p1f1_g025.nc
# tos_ann_NorESM2-LM_historical_r3i1p1f1_g025.nc
# tos_ann_E3SM-1-1_historical_r1i1p1f1_g025.nc
# tos_ann_CESM2-FV2_historical_r1i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r13i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r25i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r9i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r7i1p1f1_g025.nc
# tos_ann_NorESM2-MM_historical_r1i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-HR_historical_r10i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-HR_historical_r1i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-HR_historical_r3i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-HR_historical_r7i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-HR_historical_r6i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-HR_historical_r2i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-HR_historical_r8i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-HR_historical_r5i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-HR_historical_r9i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-HR_historical_r4i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r10i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r4i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r8i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r2i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r9i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r5i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r1i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r7i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r3i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r6i1p1f1_g025.nc
# tos_ann_INM-CM5-0_historical_r4i1p1f1_g025.nc
# tos_ann_INM-CM5-0_historical_r5i1p1f1_g025.nc
# tos_ann_INM-CM5-0_historical_r1i1p1f1_g025.nc
# tos_ann_INM-CM5-0_historical_r10i1p1f1_g025.nc
# tos_ann_INM-CM5-0_historical_r2i1p1f1_g025.nc
# tos_ann_INM-CM5-0_historical_r6i1p1f1_g025.nc
# tos_ann_INM-CM5-0_historical_r7i1p1f1_g025.nc
# tos_ann_INM-CM5-0_historical_r8i1p1f1_g025.nc
# tos_ann_INM-CM5-0_historical_r9i1p1f1_g025.nc
# tos_ann_INM-CM5-0_historical_r3i1p1f1_g025.nc
# tos_ann_CanESM5-CanOE_historical_r1i1p2f1_g025.nc
# tos_ann_CanESM5-CanOE_historical_r2i1p2f1_g025.nc
# tos_ann_CanESM5-CanOE_historical_r3i1p2f1_g025.nc
# tos_ann_HadGEM3-GC31-MM_historical_r1i1p1f3_g025.nc
# tos_ann_HadGEM3-GC31-MM_historical_r2i1p1f3_g025.nc
# tos_ann_CESM2-WACCM-FV2_historical_r1i1p1f1_g025.nc
# tos_ann_FIO-ESM-2-0_historical_r1i1p1f1_g025.nc
# tos_ann_FIO-ESM-2-0_historical_r2i1p1f1_g025.nc
# tos_ann_FIO-ESM-2-0_historical_r3i1p1f1_g025.nc
# tos_ann_INM-CM4-8_historical_r1i1p1f1_g025.nc
# tos_ann_KACE-1-0-G_historical_r2i1p1f1_g025.nc
# tos_ann_KACE-1-0-G_historical_r1i1p1f1_g025.nc
# tos_ann_KACE-1-0-G_historical_r3i1p1f1_g025.nc
# tos_ann_MPI-ESM-1-2-HAM_historical_r2i1p1f1_g025.nc
# tos_ann_MPI-ESM-1-2-HAM_historical_r1i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r1i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r3i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r2i1p1f1_g025.nc
# tos_ann_CNRM-CM6-1-HR_historical_r1i1p1f2_g025.nc
# tos_ann_E3SM-1-1-ECA_historical_r1i1p1f1_g025.nc
# tos_ann_FGOALS-f3-L_historical_r1i1p1f1_g025.nc
# tos_ann_FGOALS-f3-L_historical_r2i1p1f1_g025.nc
# tos_ann_FGOALS-f3-L_historical_r3i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_historical_r1i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_historical_r2i1p1f1_g025.nc
# tos_ann_BCC-CSM2-MR_ssp585_r1i1p1f1_g025.nc
# tos_ann_CAMS-CSM1-0_ssp585_r1i1p1f1_g025.nc
# tos_ann_CAMS-CSM1-0_ssp585_r2i1p1f1_g025.nc
# tos_ann_CNRM-CM6-1_ssp585_r1i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_ssp585_r2i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_ssp585_r3i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_ssp585_r4i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_ssp585_r5i1p1f2_g025.nc
# tos_ann_CNRM-CM6-1_ssp585_r6i1p1f2_g025.nc
# tos_ann_CNRM-ESM2-1_ssp585_r1i1p1f2_g025.nc
# tos_ann_CNRM-ESM2-1_ssp585_r2i1p1f2_g025.nc
# tos_ann_CNRM-ESM2-1_ssp585_r3i1p1f2_g025.nc
# tos_ann_CNRM-ESM2-1_ssp585_r4i1p1f2_g025.nc
# tos_ann_CNRM-ESM2-1_ssp585_r5i1p1f2_g025.nc
# tos_ann_CanESM5_ssp585_r10i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r10i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r1i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r1i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r2i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r2i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r3i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r3i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r4i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r4i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r5i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r5i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r6i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r6i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r7i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r7i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r8i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r8i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r9i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r9i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r13i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r11i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r12i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r16i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r14i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r17i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r20i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r19i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r18i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r25i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r22i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r24i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r23i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r11i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r13i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r14i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r16i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r15i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r12i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r17i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r18i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r22i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r21i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r24i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r23i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r20i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r25i1p1f1_g025.nc
# tos_ann_CanESM5_ssp585_r15i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r21i1p2f1_g025.nc
# tos_ann_CanESM5_ssp585_r19i1p1f1_g025.nc
# tos_ann_EC-Earth3-Veg_ssp585_r1i1p1f1_g025.nc
# tos_ann_EC-Earth3-Veg_ssp585_r2i1p1f1_g025.nc
# tos_ann_EC-Earth3-Veg_ssp585_r4i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r1i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r6i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r9i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r11i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r13i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r15i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r4i1p1f1_g025.nc
# tos_ann_GFDL-CM4_ssp585_r1i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_ssp585_r1i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_ssp585_r4i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_ssp585_r2i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_ssp585_r3i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_ssp585_r14i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_ssp585_r6i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r1i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r2i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r3i1p1f1_g025.nc
# tos_ann_UKESM1-0-LL_ssp585_r1i1p1f2_g025.nc
# tos_ann_UKESM1-0-LL_ssp585_r2i1p1f2_g025.nc
# tos_ann_UKESM1-0-LL_ssp585_r3i1p1f2_g025.nc
# tos_ann_UKESM1-0-LL_ssp585_r8i1p1f2_g025.nc
# tos_ann_UKESM1-0-LL_ssp585_r4i1p1f2_g025.nc
# tos_ann_CESM2_ssp585_r1i1p1f1_g025.nc
# tos_ann_CESM2_ssp585_r2i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-HR_ssp585_r1i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-HR_ssp585_r2i1p1f1_g025.nc
# tos_ann_NESM3_ssp585_r1i1p1f1_g025.nc
# tos_ann_NESM3_ssp585_r2i1p1f1_g025.nc
# tos_ann_CESM2-WACCM_ssp585_r1i1p1f1_g025.nc
# tos_ann_CESM2-WACCM_ssp585_r2i1p1f1_g025.nc
# tos_ann_CESM2-WACCM_ssp585_r4i1p1f1_g025.nc
# tos_ann_CESM2-WACCM_ssp585_r3i1p1f1_g025.nc
# tos_ann_CESM2-WACCM_ssp585_r5i1p1f1_g025.nc
# tos_ann_MIROC-ES2L_ssp585_r1i1p1f2_g025.nc
# tos_ann_MRI-ESM2-0_ssp585_r1i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r10i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r9i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r1i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r3i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r2i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r4i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r5i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r8i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r7i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r6i1p1f1_g025.nc
# tos_ann_FIO-ESM-2-0_ssp585_r1i1p1f1_g025.nc
# tos_ann_FIO-ESM-2-0_ssp585_r2i1p1f1_g025.nc
# tos_ann_FIO-ESM-2-0_ssp585_r3i1p1f1_g025.nc
# tos_ann_CanESM5-CanOE_ssp585_r1i1p2f1_g025.nc
# tos_ann_CanESM5-CanOE_ssp585_r2i1p2f1_g025.nc
# tos_ann_CanESM5-CanOE_ssp585_r3i1p2f1_g025.nc
# tos_ann_CNRM-CM6-1-HR_ssp585_r1i1p1f2_g025.nc
# tos_ann_HadGEM3-GC31-LL_ssp585_r1i1p1f3_g025.nc
# tos_ann_HadGEM3-GC31-LL_ssp585_r3i1p1f3_g025.nc
# tos_ann_HadGEM3-GC31-LL_ssp585_r2i1p1f3_g025.nc
# tos_ann_GFDL-ESM4_ssp585_r1i1p1f1_g025.nc
# tos_ann_MCM-UA-1-0_ssp585_r1i1p1f2_g025.nc
# tos_ann_INM-CM4-8_ssp585_r1i1p1f1_g025.nc
# tos_ann_INM-CM5-0_ssp585_r1i1p1f1_g025.nc
# tos_ann_KACE-1-0-G_ssp585_r1i1p1f1_g025.nc
# tos_ann_KACE-1-0-G_ssp585_r2i1p1f1_g025.nc
# tos_ann_KACE-1-0-G_ssp585_r3i1p1f1_g025.nc
# tos_ann_NorESM2-LM_ssp585_r1i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r1i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r3i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r2i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_ssp585_r1i1p1f1_g025.nc
# tos_ann_NorESM2-MM_ssp585_r1i1p1f1_g025.nc
# tos_ann_FGOALS-f3-L_ssp585_r1i1p1f1_g025.nc
# tos_ann_FGOALS-g3_ssp585_r1i1p1f1_g025.nc
# tos_ann_FGOALS-g3_ssp585_r3i1p1f1_g025.nc
# tos_ann_FGOALS-g3_ssp585_r4i1p1f1_g025.nc
# tos_ann_FGOALS-g3_ssp585_r2i1p1f1_g025.nc
# tos_ann_CIESM_historical_r3i1p1f1_g025.nc
# tos_ann_GISS-E2-1-G_ssp585_r1i1p3f1_g025.nc
# tos_ann_GISS-E2-1-G_ssp585_r1i1p1f2_g025.nc
# tos_ann_EC-Earth3_historical_r25i1p1f1_g025.nc
# tos_ann_EC-Earth3_historical_r10i1p1f1_g025.nc
# tos_ann_MIROC-ES2L_historical_r10i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r6i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r5i1p1f2_g025.nc
# tos_ann_MRI-ESM2-0_historical_r1i2p1f1_g025.nc
# tos_ann_FGOALS-g3_historical_r4i1p1f1_g025.nc
# tos_ann_CNRM-ESM2-1_historical_r9i1p1f2_g025.nc
# tos_ann_EC-Earth3_historical_r2i1p1f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r5i1p1f3_g025.nc
# tos_ann_GISS-E2-1-G_historical_r1i1p5f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r2i1p1f3_g025.nc
# tos_ann_GISS-E2-1-G_historical_r4i1p1f3_g025.nc
# tos_ann_MIROC-ES2L_historical_r7i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r8i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r9i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r4i1p1f2_g025.nc
# tos_ann_CESM2-WACCM-FV2_historical_r3i1p1f1_g025.nc
# tos_ann_CESM2-WACCM-FV2_historical_r2i1p1f1_g025.nc
# tos_ann_FGOALS-g3_historical_r2i1p1f1_g025.nc
# tos_ann_FGOALS-g3_historical_r3i1p1f1_g025.nc
# tos_ann_CAS-ESM2-0_historical_r2i1p1f1_g025.nc
# tos_ann_CAS-ESM2-0_historical_r4i1p1f1_g025.nc
# tos_ann_CAS-ESM2-0_historical_r1i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_ssp585_r1i2p1f1_g025.nc
# tos_ann_CIESM_ssp585_r1i1p1f1_g025.nc
# tos_ann_CNRM-ESM2-1_historical_r11i1p1f2_g025.nc
# tos_ann_EC-Earth3-Veg_historical_r5i1p1f1_g025.nc
# tos_ann_EC-Earth3_historical_r23i1p1f1_g025.nc
# tos_ann_EC-Earth3_historical_r3i1p1f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r3i1p1f3_g025.nc
# tos_ann_GISS-E2-1-G_historical_r1i1p1f3_g025.nc
# tos_ann_GISS-E2-1-G_historical_r10i1p3f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r2i1p5f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r4i1p5f1_g025.nc
# tos_ann_GISS-E2-1-G_historical_r3i1p5f1_g025.nc
# tos_ann_MIROC6_historical_r22i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r24i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r41i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r14i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r25i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r21i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r28i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r49i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r18i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r16i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r33i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r30i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r23i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r48i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r39i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r17i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r31i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r36i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r15i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r37i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r13i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r19i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r35i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r32i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r43i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r29i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r26i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r20i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r50i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r40i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r11i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r38i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r44i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r34i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r12i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r45i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r47i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r27i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r46i1p1f1_g025.nc
# tos_ann_MIROC6_historical_r42i1p1f1_g025.nc
# tos_ann_CESM2-FV2_historical_r3i1p1f1_g025.nc
# tos_ann_CESM2-FV2_historical_r2i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_historical_r3i1p1f1_g025.nc
# tos_ann_CIESM_historical_r2i1p1f1_g025.nc
# tos_ann_AWI-ESM-1-1-LR_historical_r1i1p1f1_g025.nc
# tos_ann_FGOALS-g3_historical_r5i1p1f1_g025.nc
# tos_ann_FGOALS-g3_historical_r1i1p1f1_g025.nc
# tos_ann_CAS-ESM2-0_historical_r3i1p1f1_g025.nc
# tos_ann_EC-Earth3-Veg-LR_historical_r1i1p1f1_g025.nc
# tos_ann_EC-Earth3-Veg-LR_historical_r2i1p1f1_g025.nc
# tos_ann_EC-Earth3-Veg-LR_historical_r3i1p1f1_g025.nc
# tos_ann_EC-Earth3-Veg_ssp585_r3i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_ssp585_r2i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_ssp585_r3i1p1f1_g025.nc
# tos_ann_FGOALS-f3-L_ssp585_r2i1p1f1_g025.nc
# tos_ann_FGOALS-f3-L_ssp585_r3i1p1f1_g025.nc
# tos_ann_AWI-CM-1-1-MR_ssp585_r1i1p1f1_g025.nc
# tos_ann_CESM2_ssp585_r4i1p1f1_g025.nc
# tos_ann_CESM2_ssp585_r11i1p1f1_g025.nc
# tos_ann_CESM2_ssp585_r10i1p1f1_g025.nc
# tos_ann_EC-Earth3-Veg_historical_r6i1p1f1_g025.nc
# tos_ann_HadGEM3-GC31-MM_historical_r4i1p1f3_g025.nc
# tos_ann_HadGEM3-GC31-MM_historical_r3i1p1f3_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r4i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r10i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r5i1p1f1_g025.nc
# tos_ann_CMCC-CM2-SR5_historical_r1i1p1f1_g025.nc
# tos_ann_HadGEM3-GC31-LL_ssp585_r4i1p1f3_g025.nc
# tos_ann_HadGEM3-GC31-MM_ssp585_r1i1p1f3_g025.nc
# tos_ann_HadGEM3-GC31-MM_ssp585_r3i1p1f3_g025.nc
# tos_ann_HadGEM3-GC31-MM_ssp585_r2i1p1f3_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r6i1p1f1_g025.nc
# tos_ann_TaiESM1_historical_r1i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r11i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r17i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r16i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r15i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r14i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r19i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r13i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r20i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r21i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r23i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r25i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r24i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r22i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r35i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r33i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r29i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r34i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r31i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r26i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r28i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r27i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r32i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r36i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r38i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r37i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r9i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r46i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r5i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r44i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r41i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r40i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r8i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r43i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r48i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r9i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r8i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r49i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r47i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r7i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r6i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r39i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r10i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r50i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r45i1p1f1_g025.nc
# tos_ann_CMCC-CM2-SR5_ssp585_r1i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r4i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r12i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r18i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r30i1p1f1_g025.nc
# tos_ann_MIROC6_ssp585_r42i1p1f1_g025.nc
# tos_ann_CanESM5_historical_r26i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r39i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r30i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r27i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r31i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r29i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r28i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r34i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r40i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r38i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r36i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r32i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r37i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r35i1p2f1_g025.nc
# tos_ann_CanESM5_historical_r33i1p2f1_g025.nc
# tos_ann_EC-Earth3-Veg_ssp585_r6i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r105i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r102i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r101i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r104i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r108i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r111i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r114i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r118i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r117i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r116i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r121i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r122i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r127i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r128i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r129i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r130i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r126i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r125i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r109i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r106i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r110i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r103i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r107i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r119i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r113i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r115i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r120i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r112i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r123i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r124i1p1f1_g025.nc
# tos_ann_NorESM2-MM_historical_r2i1p1f1_g025.nc
# tos_ann_UKESM1-0-LL_historical_r13i1p1f2_g025.nc
# tos_ann_NorESM2-MM_historical_r3i1p1f1_g025.nc
# tos_ann_FGOALS-g3_historical_r6i1p1f1_g025.nc
# tos_ann_CMCC-CM2-HR4_historical_r1i1p1f1_g025.nc
# tos_ann_KIOST-ESM_historical_r1i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r135i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r137i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r132i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r140i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r136i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r138i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r139i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r131i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r133i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r134i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r146i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r148i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r144i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r142i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r141i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r145i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r147i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r143i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r149i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r150i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r16i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r17i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r18i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r14i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r20i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r15i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r11i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r19i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r13i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r12i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r7i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r9i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r5i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r8i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r10i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r6i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r4i1p1f1_g025.nc
# tos_ann_KIOST-ESM_ssp585_r1i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_historical_r1i1000p1f1_g025.nc
# tos_ann_GFDL-ESM4_historical_r2i1p1f1_g025.nc
# tos_ann_GFDL-ESM4_historical_r3i1p1f1_g025.nc
# tos_ann_HadGEM3-GC31-MM_ssp585_r4i1p1f3_g025.nc
# tos_ann_EC-Earth3-AerChem_historical_r1i1p1f1_g025.nc
# tos_ann_EC-Earth3_ssp585_r3i1p1f1_g025.nc
# tos_ann_CIESM_historical_r1i1p1f1_g025.nc
# tos_ann_EC-Earth3-Veg_historical_r12i1p1f1_g025.nc
# tos_ann_EC-Earth3-Veg_historical_r14i1p1f1_g025.nc
# tos_ann_E3SM-1-1_ssp585_r1i1p1f1_g025.nc
# tos_ann_MPI-ESM-1-2-HAM_historical_r3i1p1f1_g025.nc
# tos_ann_MIROC-ES2L_ssp585_r3i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_ssp585_r10i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_ssp585_r2i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_ssp585_r5i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_ssp585_r7i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_ssp585_r6i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_ssp585_r8i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_ssp585_r9i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_ssp585_r4i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r1i1000p1f2_g025.nc
# tos_ann_GISS-E2-1-H_historical_r5i1p5f1_g025.nc
# tos_ann_GISS-E2-1-H_historical_r4i1p5f1_g025.nc
# tos_ann_CMCC-ESM2_historical_r1i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r26i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r10i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r14i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r16i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r22i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r20i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r18i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r1i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r19i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r29i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r3i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r28i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r30i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r27i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r6i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r4i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r5i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r17i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r24i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r23i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r15i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r11i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r12i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r21i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r2i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r8i1p1f1_g025.nc
# tos_ann_HadGEM3-GC31-LL_historical_r5i1p1f3_g025.nc
# tos_ann_MIROC-ES2L_historical_r14i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r15i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r30i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r13i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r11i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r12i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r17i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r16i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r25i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r19i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r20i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r18i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r21i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r22i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r23i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r24i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r26i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r28i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r29i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r27i1p1f2_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r7i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r21i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r22i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r23i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r24i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r25i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r26i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r27i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r28i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r29i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r30i1p1f1_g025.nc
# tos_ann_IPSL-CM5A2-INCA_historical_r1i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR-INCA_historical_r1i1p1f1_g025.nc
# tos_ann_TaiESM1_ssp585_r1i1p1f1_g025.nc
# tos_ann_CAS-ESM2-0_ssp585_r1i1p1f1_g025.nc
# tos_ann_CAS-ESM2-0_ssp585_r3i1p1f1_g025.nc
# tos_ann_CMCC-ESM2_ssp585_r1i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r31i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r32i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r33i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r34i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r35i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r36i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r37i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r38i1p1f1_g025.nc
# tos_ann_GISS-E2-1-G_ssp585_r2i1p1f2_g025.nc
# tos_ann_GISS-E2-1-G_ssp585_r3i1p1f2_g025.nc
# tos_ann_GISS-E2-1-G_ssp585_r4i1p1f2_g025.nc
# tos_ann_GISS-E2-1-G_ssp585_r5i1p1f2_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r39i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r40i1p1f1_g025.nc
# tos_ann_ICON-ESM-LR_historical_r1i1p1f1_g025.nc
# tos_ann_ICON-ESM-LR_historical_r2i1p1f1_g025.nc
# tos_ann_ICON-ESM-LR_historical_r3i1p1f1_g025.nc
# tos_ann_ICON-ESM-LR_historical_r4i1p1f1_g025.nc
# tos_ann_ICON-ESM-LR_historical_r5i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_historical_r10i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_historical_r7i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_historical_r8i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_historical_r6i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_historical_r9i1p1f1_g025.nc
# tos_ann_GISS-E2-2-H_historical_r1i1p1f1_g025.nc
# tos_ann_GISS-E2-2-H_historical_r2i1p1f1_g025.nc
# tos_ann_GISS-E2-2-H_historical_r3i1p1f1_g025.nc
# tos_ann_GISS-E2-2-H_historical_r4i1p1f1_g025.nc
# tos_ann_GISS-E2-2-H_historical_r5i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_ssp585_r2i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_ssp585_r3i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_ssp585_r4i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_ssp585_r5i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_historical_r4i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_historical_r5i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_ssp585_r4i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_ssp585_r5i1p1f1_g025.nc
# tos_ann_GISS-E2-1-H_ssp585_r1i1p1f2_g025.nc
# tos_ann_CMCC-CM2-SR5_historical_r2i1p2f1_g025.nc
# tos_ann_CMCC-CM2-SR5_historical_r3i1p2f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r11i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r12i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r13i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r14i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r15i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r16i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r17i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r18i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r19i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r20i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r31i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r26i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r21i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r35i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r23i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r30i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r33i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r34i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r28i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r32i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r29i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r36i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r37i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r38i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r39i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r27i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r24i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r22i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r40i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r25i1p1f1_g025.nc
# tos_ann_GISS-E2-1-H_ssp585_r2i1p1f2_g025.nc
# tos_ann_GISS-E2-1-H_ssp585_r3i1p1f2_g025.nc
# tos_ann_GISS-E2-1-H_ssp585_r4i1p1f2_g025.nc
# tos_ann_GISS-E2-1-H_ssp585_r5i1p1f2_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r11i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r12i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r14i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r15i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r16i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r17i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r18i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r19i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r20i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r21i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r22i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r23i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r24i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r25i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r26i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r27i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r28i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r29i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r30i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r33i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r13i1p1f1_g025.nc
# tos_ann_CMCC-CM2-SR5_historical_r4i1p2f1_g025.nc
# tos_ann_CMCC-CM2-SR5_historical_r5i1p2f1_g025.nc
# tos_ann_CMCC-CM2-SR5_historical_r6i1p2f1_g025.nc
# tos_ann_CMCC-CM2-SR5_historical_r7i1p2f1_g025.nc
# tos_ann_IPSL-CM6A-LR_ssp585_r33i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r11i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r12i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r13i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r14i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r15i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r16i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r17i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r18i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r19i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r20i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r21i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r22i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r23i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r24i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r25i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r26i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r27i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r28i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r29i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r30i1p1f1_g025.nc
# tos_ann_CMCC-CM2-SR5_historical_r8i1p2f1_g025.nc
# tos_ann_CMCC-CM2-SR5_historical_r9i1p2f1_g025.nc
# tos_ann_CMCC-CM2-SR5_historical_r10i1p2f1_g025.nc
# tos_ann_CMCC-CM2-SR5_historical_r11i1p2f1_g025.nc
# tos_ann_MIROC-ES2H_historical_r1i1p4f2_g025.nc
# tos_ann_MIROC-ES2H_historical_r2i1p4f2_g025.nc
# tos_ann_MIROC-ES2H_historical_r3i1p4f2_g025.nc
# tos_ann_GISS-E2-1-H_ssp585_r1i1p3f1_g025.nc
# tos_ann_GISS-E2-1-H_ssp585_r2i1p3f1_g025.nc
# tos_ann_GISS-E2-1-H_ssp585_r3i1p3f1_g025.nc
# tos_ann_GISS-E2-1-H_ssp585_r4i1p3f1_g025.nc
# tos_ann_GISS-E2-1-H_ssp585_r5i1p3f1_g025.nc
# tos_ann_E3SM-1-1-ECA_ssp585_r1i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r1i2000p1f1_g025.nc
# tos_ann_GISS-E2-2-G_historical_r1i1p1f1_g025.nc
# tos_ann_GISS-E2-2-G_historical_r1i1p3f1_g025.nc
# tos_ann_GISS-E2-2-G_historical_r2i1p1f1_g025.nc
# tos_ann_GISS-E2-2-G_historical_r2i1p3f1_g025.nc
# tos_ann_GISS-E2-2-G_historical_r3i1p1f1_g025.nc
# tos_ann_GISS-E2-2-G_historical_r3i1p3f1_g025.nc
# tos_ann_GISS-E2-2-G_historical_r4i1p1f1_g025.nc
# tos_ann_GISS-E2-2-G_historical_r4i1p3f1_g025.nc
# tos_ann_GISS-E2-2-G_historical_r5i1p1f1_g025.nc
# tos_ann_GISS-E2-2-G_historical_r5i1p3f1_g025.nc
# tos_ann_GISS-E2-2-G_historical_r6i1p1f1_g025.nc
# tos_ann_UKESM1-1-LL_historical_r1i1p1f2_g025.nc
# tos_ann_GISS-E2-1-G_ssp585_r2i1p5f1_g025.nc
# tos_ann_GISS-E2-1-G_ssp585_r3i1p5f1_g025.nc
# tos_ann_GISS-E2-1-G_ssp585_r4i1p5f1_g025.nc
# tos_ann_GISS-E2-1-G_ssp585_r5i1p5f1_g025.nc
# tos_ann_IITM-ESM_ssp585_r1i1p1f1_g025.nc
# tos_ann_GISS-E2-2-G_ssp585_r1i1p3f1_g025.nc
# tos_ann_GISS-E2-2-G_ssp585_r2i1p3f1_g025.nc
# tos_ann_GISS-E2-2-G_ssp585_r3i1p3f1_g025.nc
# tos_ann_GISS-E2-2-G_ssp585_r4i1p3f1_g025.nc
# tos_ann_GISS-E2-2-G_ssp585_r5i1p3f1_g025.nc
# tos_ann_GISS-E3-G_historical_r1i1p1f1_g025.nc
# tos_ann_CESM2-FV2_historical_r1i2p2f1_g025.nc
# tos_ann_CESM2-FV2_ssp585_r1i2p2f1_g025.nc
# tos_ann_ACCESS-CM2_historical_r10i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_historical_r6i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_historical_r7i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_historical_r8i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_historical_r9i1p1f1_g025.nc
# tos_ann_E3SM-2-0_historical_r1i1p1f1_g025.nc
# tos_ann_E3SM-2-0_historical_r2i1p1f1_g025.nc
# tos_ann_E3SM-2-0_historical_r3i1p1f1_g025.nc
# tos_ann_E3SM-2-0_historical_r4i1p1f1_g025.nc
# tos_ann_E3SM-2-0_historical_r5i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r11i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r12i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r13i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r17i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r10i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r10i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r11i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r12i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r15i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r15i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r16i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r16i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r17i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r18i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r19i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r19i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r23i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r25i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r27i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r28i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r2i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r33i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r37i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r42i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r47i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r13i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r14i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r14i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r18i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r1i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r20i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r20i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r21i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r24i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r24i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r25i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r26i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r29i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r2i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r31i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r32i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r35i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r36i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r39i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r3i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r3i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r43i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r44i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r45i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r46i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r48i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r49i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r4i1p1f1_g025.nc
# ...
# tos_ann_NorCPM1_historical_r28i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r30i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r27i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r6i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r4i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r5i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r17i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r24i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r23i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r15i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r11i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r12i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r21i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r2i1p1f1_g025.nc
# tos_ann_NorCPM1_historical_r8i1p1f1_g025.nc
# tos_ann_HadGEM3-GC31-LL_historical_r5i1p1f3_g025.nc
# tos_ann_MIROC-ES2L_historical_r14i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r15i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r30i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r13i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r11i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r12i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r17i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r16i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r25i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r19i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r20i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r18i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r21i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r22i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r23i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r24i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r26i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r28i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r29i1p1f2_g025.nc
# tos_ann_MIROC-ES2L_historical_r27i1p1f2_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r7i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r21i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r22i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r23i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r24i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r25i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r26i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r27i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r28i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r29i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r30i1p1f1_g025.nc
# tos_ann_IPSL-CM5A2-INCA_historical_r1i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR-INCA_historical_r1i1p1f1_g025.nc
# tos_ann_TaiESM1_ssp585_r1i1p1f1_g025.nc
# tos_ann_CAS-ESM2-0_ssp585_r1i1p1f1_g025.nc
# tos_ann_CAS-ESM2-0_ssp585_r3i1p1f1_g025.nc
# tos_ann_CMCC-ESM2_ssp585_r1i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r31i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r32i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r33i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r34i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r35i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r36i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r37i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r38i1p1f1_g025.nc
# tos_ann_GISS-E2-1-G_ssp585_r2i1p1f2_g025.nc
# tos_ann_GISS-E2-1-G_ssp585_r3i1p1f2_g025.nc
# tos_ann_GISS-E2-1-G_ssp585_r4i1p1f2_g025.nc
# tos_ann_GISS-E2-1-G_ssp585_r5i1p1f2_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r39i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_historical_r40i1p1f1_g025.nc
# tos_ann_ICON-ESM-LR_historical_r1i1p1f1_g025.nc
# tos_ann_ICON-ESM-LR_historical_r2i1p1f1_g025.nc
# tos_ann_ICON-ESM-LR_historical_r3i1p1f1_g025.nc
# tos_ann_ICON-ESM-LR_historical_r4i1p1f1_g025.nc
# tos_ann_ICON-ESM-LR_historical_r5i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_historical_r10i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_historical_r7i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_historical_r8i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_historical_r6i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_historical_r9i1p1f1_g025.nc
# tos_ann_GISS-E2-2-H_historical_r1i1p1f1_g025.nc
# tos_ann_GISS-E2-2-H_historical_r2i1p1f1_g025.nc
# tos_ann_GISS-E2-2-H_historical_r3i1p1f1_g025.nc
# tos_ann_GISS-E2-2-H_historical_r4i1p1f1_g025.nc
# tos_ann_GISS-E2-2-H_historical_r5i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_ssp585_r2i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_ssp585_r3i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_ssp585_r4i1p1f1_g025.nc
# tos_ann_MRI-ESM2-0_ssp585_r5i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_historical_r4i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_historical_r5i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_ssp585_r4i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_ssp585_r5i1p1f1_g025.nc
# tos_ann_GISS-E2-1-H_ssp585_r1i1p1f2_g025.nc
# tos_ann_CMCC-CM2-SR5_historical_r2i1p2f1_g025.nc
# tos_ann_CMCC-CM2-SR5_historical_r3i1p2f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r11i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r12i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r13i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r14i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r15i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r16i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r17i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r18i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r19i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r20i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r31i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r26i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r21i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r35i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r23i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r30i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r33i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r34i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r28i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r32i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r29i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r36i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r37i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r38i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r39i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r27i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r24i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r22i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r40i1p1f1_g025.nc
# tos_ann_ACCESS-ESM1-5_ssp585_r25i1p1f1_g025.nc
# tos_ann_GISS-E2-1-H_ssp585_r2i1p1f2_g025.nc
# tos_ann_GISS-E2-1-H_ssp585_r3i1p1f2_g025.nc
# tos_ann_GISS-E2-1-H_ssp585_r4i1p1f2_g025.nc
# tos_ann_GISS-E2-1-H_ssp585_r5i1p1f2_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r11i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r12i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r14i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r15i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r16i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r17i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r18i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r19i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r20i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r21i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r22i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r23i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r24i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r25i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r26i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r27i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r28i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r29i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r30i1p1f1_g025.nc
# tos_ann_IPSL-CM6A-LR_historical_r33i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r13i1p1f1_g025.nc
# tos_ann_CMCC-CM2-SR5_historical_r4i1p2f1_g025.nc
# tos_ann_CMCC-CM2-SR5_historical_r5i1p2f1_g025.nc
# tos_ann_CMCC-CM2-SR5_historical_r6i1p2f1_g025.nc
# tos_ann_CMCC-CM2-SR5_historical_r7i1p2f1_g025.nc
# tos_ann_IPSL-CM6A-LR_ssp585_r33i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r11i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r12i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r13i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r14i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r15i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r16i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r17i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r18i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r19i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r20i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r21i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r22i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r23i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r24i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r25i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r26i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r27i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r28i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r29i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_ssp585_r30i1p1f1_g025.nc
# tos_ann_CMCC-CM2-SR5_historical_r8i1p2f1_g025.nc
# tos_ann_CMCC-CM2-SR5_historical_r9i1p2f1_g025.nc
# tos_ann_CMCC-CM2-SR5_historical_r10i1p2f1_g025.nc
# tos_ann_CMCC-CM2-SR5_historical_r11i1p2f1_g025.nc
# tos_ann_MIROC-ES2H_historical_r1i1p4f2_g025.nc
# tos_ann_MIROC-ES2H_historical_r2i1p4f2_g025.nc
# tos_ann_MIROC-ES2H_historical_r3i1p4f2_g025.nc
# tos_ann_GISS-E2-1-H_ssp585_r1i1p3f1_g025.nc
# tos_ann_GISS-E2-1-H_ssp585_r2i1p3f1_g025.nc
# tos_ann_GISS-E2-1-H_ssp585_r3i1p3f1_g025.nc
# tos_ann_GISS-E2-1-H_ssp585_r4i1p3f1_g025.nc
# tos_ann_GISS-E2-1-H_ssp585_r5i1p3f1_g025.nc
# tos_ann_E3SM-1-1-ECA_ssp585_r1i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r1i2000p1f1_g025.nc
# tos_ann_GISS-E2-2-G_historical_r1i1p1f1_g025.nc
# tos_ann_GISS-E2-2-G_historical_r1i1p3f1_g025.nc
# tos_ann_GISS-E2-2-G_historical_r2i1p1f1_g025.nc
# tos_ann_GISS-E2-2-G_historical_r2i1p3f1_g025.nc
# tos_ann_GISS-E2-2-G_historical_r3i1p1f1_g025.nc
# tos_ann_GISS-E2-2-G_historical_r3i1p3f1_g025.nc
# tos_ann_GISS-E2-2-G_historical_r4i1p1f1_g025.nc
# tos_ann_GISS-E2-2-G_historical_r4i1p3f1_g025.nc
# tos_ann_GISS-E2-2-G_historical_r5i1p1f1_g025.nc
# tos_ann_GISS-E2-2-G_historical_r5i1p3f1_g025.nc
# tos_ann_GISS-E2-2-G_historical_r6i1p1f1_g025.nc
# tos_ann_UKESM1-1-LL_historical_r1i1p1f2_g025.nc
# tos_ann_GISS-E2-1-G_ssp585_r2i1p5f1_g025.nc
# tos_ann_GISS-E2-1-G_ssp585_r3i1p5f1_g025.nc
# tos_ann_GISS-E2-1-G_ssp585_r4i1p5f1_g025.nc
# tos_ann_GISS-E2-1-G_ssp585_r5i1p5f1_g025.nc
# tos_ann_IITM-ESM_ssp585_r1i1p1f1_g025.nc
# tos_ann_GISS-E2-2-G_ssp585_r1i1p3f1_g025.nc
# tos_ann_GISS-E2-2-G_ssp585_r2i1p3f1_g025.nc
# tos_ann_GISS-E2-2-G_ssp585_r3i1p3f1_g025.nc
# tos_ann_GISS-E2-2-G_ssp585_r4i1p3f1_g025.nc
# tos_ann_GISS-E2-2-G_ssp585_r5i1p3f1_g025.nc
# tos_ann_GISS-E3-G_historical_r1i1p1f1_g025.nc
# tos_ann_CESM2-FV2_historical_r1i2p2f1_g025.nc
# tos_ann_CESM2-FV2_ssp585_r1i2p2f1_g025.nc
# tos_ann_ACCESS-CM2_historical_r10i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_historical_r6i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_historical_r7i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_historical_r8i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_historical_r9i1p1f1_g025.nc
# tos_ann_E3SM-2-0_historical_r1i1p1f1_g025.nc
# tos_ann_E3SM-2-0_historical_r2i1p1f1_g025.nc
# tos_ann_E3SM-2-0_historical_r3i1p1f1_g025.nc
# tos_ann_E3SM-2-0_historical_r4i1p1f1_g025.nc
# tos_ann_E3SM-2-0_historical_r5i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r11i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r12i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r13i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r17i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r10i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r10i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r11i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r12i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r15i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r15i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r16i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r16i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r17i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r18i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r19i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r19i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r23i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r25i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r27i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r28i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r2i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r33i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r37i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r42i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r47i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r13i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r14i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r14i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r18i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r1i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r20i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r20i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r21i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r24i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r24i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r25i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r26i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r29i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r2i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r31i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r32i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r35i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r36i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r39i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r3i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r3i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r43i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r44i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r45i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r46i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r48i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r49i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r4i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r4i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r50i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r5i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r7i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r7i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r8i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r9i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r1i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r22i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r41i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r6i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r8i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r9i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r22i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r30i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r34i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r38i1p1f1_g025.nc
# tos_ann_CanESM5-1_historical_r5i1p2f1_g025.nc
# tos_ann_CanESM5-1_historical_r6i1p2f1_g025.nc
# tos_ann_CanESM5-1_ssp585_r10i1p1f1_g025.nc
# tos_ann_CanESM5-1_ssp585_r10i1p2f1_g025.nc
# tos_ann_CanESM5-1_ssp585_r1i1p1f1_g025.nc
# tos_ann_CanESM5-1_ssp585_r1i1p2f1_g025.nc
# tos_ann_CanESM5-1_ssp585_r2i1p1f1_g025.nc
# tos_ann_CanESM5-1_ssp585_r3i1p1f1_g025.nc
# tos_ann_CanESM5-1_ssp585_r3i1p2f1_g025.nc
# tos_ann_CanESM5-1_ssp585_r4i1p1f1_g025.nc
# tos_ann_CanESM5-1_ssp585_r4i1p2f1_g025.nc
# tos_ann_CanESM5-1_ssp585_r5i1p1f1_g025.nc
# tos_ann_CanESM5-1_ssp585_r6i1p1f1_g025.nc
# tos_ann_CanESM5-1_ssp585_r6i1p2f1_g025.nc
# tos_ann_CanESM5-1_ssp585_r7i1p1f1_g025.nc
# tos_ann_CanESM5-1_ssp585_r7i1p2f1_g025.nc
# tos_ann_CanESM5-1_ssp585_r8i1p1f1_g025.nc
# tos_ann_CanESM5-1_ssp585_r8i1p2f1_g025.nc
# tos_ann_CanESM5-1_ssp585_r9i1p1f1_g025.nc
# tos_ann_CanESM5-1_ssp585_r9i1p2f1_g025.nc
# tos_ann_ACCESS-CM2_ssp585_r10i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_ssp585_r6i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_ssp585_r7i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_ssp585_r8i1p1f1_g025.nc
# tos_ann_ACCESS-CM2_ssp585_r9i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r31i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r32i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r33i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r34i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r37i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r38i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r39i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r40i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r47i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r48i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r50i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r35i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r36i1p1f1_g025.nc
# tos_ann_MPI-ESM1-2-LR_historical_r49i1p1f1_g025.nc
# tos_ann_E3SM-2-0_historical_r10i1p1f1_g025.nc
# tos_ann_E3SM-2-0_historical_r6i1p1f1_g025.nc
# tos_ann_E3SM-2-0_historical_r7i1p1f1_g025.nc
# tos_ann_E3SM-2-0_historical_r8i1p1f1_g025.nc
# tos_ann_E3SM-2-0_historical_r9i1p1f1_g025.nc
# tos_ann_E3SM-2-0-NARRM_historical_r1i1p1f1_g025.nc
# tos_ann_E3SM-2-0-NARRM_historical_r3i1p1f1_g025.nc
# tos_ann_E3SM-2-0-NARRM_historical_r4i1p1f1_g025.nc
# tos_ann_E3SM-2-0-NARRM_historical_r5i1p1f1_g025.nc

# %% [markdown]
# ## 3- Split data into historical data from 1850 until 2014 and forecast data from 2014 until 2100

# %%
forcing_hist  = "historical"
forcing_ssp585 = "ssp585"
# for key in dic_model_forcing['CanESM5'][forcing_hist].keys():
#     print(dic_model_forcing['CanESM5'][forcing_hist][key].shape)
#     print(dic_model_forcing['CanESM5'][forcing_ssp585][key].shape)

# %%
forcing_hist  = "historical"
forcing_ssp585 = "ssp585"

dic_merged_runs_ssp585 = {i: [] for i in model_names}

for idx, model in enumerate(model_names):
    
    dic_merged_runs_ssp585[model] = {}

    for idx_key, key in enumerate(dic_model_forcing[model][forcing_ssp585].keys()):
        
        if key in dic_model_forcing[model][forcing_hist].keys():
            
            print(model, key)
            print(dic_model_forcing[model][forcing_hist][key].shape)
            print(dic_model_forcing[model][forcing_ssp585][key].shape)


            # load the run
            hist_run = dic_model_forcing[model][forcing_hist][key]
            future_run = dic_model_forcing[model][forcing_ssp585][key]

            # concatenate the run 
            full_run = np.concatenate([hist_run,future_run],axis=0) 
            dic_merged_runs_ssp585[model][key] = full_run
# Out:
# CanESM5-1 r10i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5-1 r10i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5-1 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5-1 r1i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5-1 r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5-1 r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5-1 r3i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5-1 r4i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5-1 r4i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5-1 r5i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5-1 r6i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5-1 r6i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5-1 r7i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5-1 r7i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5-1 r8i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5-1 r8i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5-1 r9i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5-1 r9i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CNRM-ESM2-1 r1i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CNRM-ESM2-1 r2i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CNRM-ESM2-1 r3i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CNRM-ESM2-1 r4i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CNRM-ESM2-1 r5i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# FIO-ESM-2-0 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# FIO-ESM-2-0 r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# FIO-ESM-2-0 r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-2-G r1i1p3f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-2-G r2i1p3f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-2-G r3i1p3f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-2-G r4i1p3f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-2-G r5i1p3f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CNRM-CM6-1 r1i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CNRM-CM6-1 r2i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CNRM-CM6-1 r3i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CNRM-CM6-1 r4i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CNRM-CM6-1 r5i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CNRM-CM6-1 r6i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# INM-CM5-0 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# NESM3 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# NESM3 r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# E3SM-1-1 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# BCC-CSM2-MR r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CESM2-FV2 r1i2p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC-ES2L r1i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC-ES2L r3i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC-ES2L r10i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC-ES2L r2i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC-ES2L r5i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC-ES2L r7i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC-ES2L r6i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC-ES2L r8i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC-ES2L r9i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC-ES2L r4i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CAMS-CSM1-0 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CAMS-CSM1-0 r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-HR r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-HR r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# NorESM2-LM r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CAS-ESM2-0 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CAS-ESM2-0 r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# AWI-CM-1-1-MR r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# HadGEM3-GC31-MM r1i1p1f3
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# HadGEM3-GC31-MM r3i1p1f3
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# HadGEM3-GC31-MM r2i1p1f3
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# HadGEM3-GC31-MM r4i1p1f3
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5-CanOE r1i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5-CanOE r2i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5-CanOE r3i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# EC-Earth3 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# EC-Earth3 r6i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# EC-Earth3 r9i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# EC-Earth3 r11i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# EC-Earth3 r13i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# EC-Earth3 r15i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# EC-Earth3 r4i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# EC-Earth3 r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CNRM-CM6-1-HR r1i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# KACE-1-0-G r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# KACE-1-0-G r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# KACE-1-0-G r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-H r1i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-H r2i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-H r3i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-H r4i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-H r5i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-H r1i1p3f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-H r2i1p3f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-H r3i1p3f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-H r4i1p3f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-H r5i1p3f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# EC-Earth3-Veg r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# EC-Earth3-Veg r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# EC-Earth3-Veg r4i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# EC-Earth3-Veg r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# EC-Earth3-Veg r6i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# HadGEM3-GC31-LL r1i1p1f3
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# HadGEM3-GC31-LL r3i1p1f3
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# HadGEM3-GC31-LL r2i1p1f3
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# HadGEM3-GC31-LL r4i1p1f3
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MCM-UA-1-0 r1i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CMCC-ESM2 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r11i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r17i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r16i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r15i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r14i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r19i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r13i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r20i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r21i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r23i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r25i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r24i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r22i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r35i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r33i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r29i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r34i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r31i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r26i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r28i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r27i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r32i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r36i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r38i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r37i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r9i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r46i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r5i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r44i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r41i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r40i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r8i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r43i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r48i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r49i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r47i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r7i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r6i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r39i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r10i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r50i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r45i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r4i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r12i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r18i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r30i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r42i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CESM2 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CESM2 r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CESM2 r4i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CESM2 r11i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CESM2 r10i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# INM-CM4-8 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GFDL-CM4 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# FGOALS-g3 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# FGOALS-g3 r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# FGOALS-g3 r4i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# FGOALS-g3 r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-G r1i1p3f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-G r1i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-G r2i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-G r3i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-G r4i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-G r5i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-G r2i1p5f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-G r3i1p5f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-G r4i1p5f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MRI-ESM2-0 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MRI-ESM2-0 r1i2p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MRI-ESM2-0 r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MRI-ESM2-0 r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MRI-ESM2-0 r4i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MRI-ESM2-0 r5i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CESM2-WACCM r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CESM2-WACCM r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CESM2-WACCM r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# KIOST-ESM r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r7i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r9i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r5i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r8i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r10i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r6i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r4i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r11i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r12i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r13i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r14i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r15i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r16i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r17i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r18i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r19i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r20i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r31i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r26i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r21i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r35i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r23i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r30i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r33i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r34i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r28i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r32i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r29i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r36i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r37i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r38i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r39i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r27i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r24i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r22i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r40i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r25i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# IPSL-CM6A-LR r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# IPSL-CM6A-LR r4i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# IPSL-CM6A-LR r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# IPSL-CM6A-LR r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# IPSL-CM6A-LR r14i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# IPSL-CM6A-LR r6i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# IPSL-CM6A-LR r33i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CMCC-CM2-SR5 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r10i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r10i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r1i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r2i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r3i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r4i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r4i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r5i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r5i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r6i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r6i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r7i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r7i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r8i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r8i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r9i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r9i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r13i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r11i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r12i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r16i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r14i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r17i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r20i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r19i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r18i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r25i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r22i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r24i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r23i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r11i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r13i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r14i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r16i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r15i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r12i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r17i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r18i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r22i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r21i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r24i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r23i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r20i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r25i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r15i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r21i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r19i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# TaiESM1 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-CM2 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-CM2 r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-CM2 r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-CM2 r4i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-CM2 r5i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-CM2 r10i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-CM2 r6i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-CM2 r7i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-CM2 r8i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-CM2 r9i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CIESM r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GFDL-ESM4 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r10i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r9i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r4i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r5i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r8i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r7i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r6i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r11i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r12i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r13i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r14i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r15i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r16i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r17i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r18i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r19i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r20i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r21i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r22i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r23i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r24i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r25i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r26i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r27i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r28i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r29i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r30i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# NorESM2-MM r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# FGOALS-f3-L r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# FGOALS-f3-L r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# FGOALS-f3-L r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# E3SM-1-1-ECA r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# UKESM1-0-LL r1i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# UKESM1-0-LL r2i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# UKESM1-0-LL r3i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# UKESM1-0-LL r8i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# UKESM1-0-LL r4i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# (251, 72, 144)
# MIROC6 r41i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r40i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r8i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r43i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r48i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r49i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r47i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r7i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r6i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r39i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r10i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r50i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r45i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r4i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r12i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r18i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r30i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MIROC6 r42i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CESM2 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CESM2 r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CESM2 r4i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CESM2 r11i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CESM2 r10i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# INM-CM4-8 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GFDL-CM4 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# FGOALS-g3 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# FGOALS-g3 r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# FGOALS-g3 r4i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# FGOALS-g3 r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-G r1i1p3f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-G r1i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-G r2i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-G r3i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-G r4i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-G r5i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-G r2i1p5f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-G r3i1p5f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GISS-E2-1-G r4i1p5f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MRI-ESM2-0 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MRI-ESM2-0 r1i2p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MRI-ESM2-0 r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MRI-ESM2-0 r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MRI-ESM2-0 r4i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MRI-ESM2-0 r5i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CESM2-WACCM r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CESM2-WACCM r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CESM2-WACCM r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# KIOST-ESM r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r7i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r9i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r5i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r8i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r10i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r6i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r4i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r11i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r12i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r13i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r14i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r15i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r16i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r17i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r18i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r19i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r20i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r31i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r26i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r21i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r35i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r23i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r30i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r33i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r34i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r28i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r32i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r29i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r36i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r37i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r38i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r39i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r27i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r24i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r22i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r40i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-ESM1-5 r25i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# IPSL-CM6A-LR r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# IPSL-CM6A-LR r4i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# IPSL-CM6A-LR r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# IPSL-CM6A-LR r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# IPSL-CM6A-LR r14i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# IPSL-CM6A-LR r6i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# IPSL-CM6A-LR r33i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CMCC-CM2-SR5 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r10i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r10i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r1i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r2i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r3i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r4i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r4i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r5i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r5i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r6i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r6i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r7i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r7i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r8i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r8i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r9i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r9i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r13i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r11i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r12i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r16i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r14i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r17i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r20i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r19i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r18i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r25i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r22i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r24i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r23i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r11i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r13i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r14i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r16i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r15i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r12i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r17i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r18i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r22i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r21i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r24i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r23i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r20i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r25i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r15i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r21i1p2f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CanESM5 r19i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# TaiESM1 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-CM2 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-CM2 r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-CM2 r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-CM2 r4i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-CM2 r5i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-CM2 r10i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-CM2 r6i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-CM2 r7i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-CM2 r8i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# ACCESS-CM2 r9i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# CIESM r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# GFDL-ESM4 r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r10i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r9i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r4i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r5i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r8i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r7i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r6i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r11i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r12i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r13i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r14i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r15i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r16i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r17i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r18i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r19i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r20i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r21i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r22i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r23i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r24i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r25i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r26i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r27i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r28i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r29i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# MPI-ESM1-2-LR r30i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# NorESM2-MM r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# FGOALS-f3-L r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# FGOALS-f3-L r2i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# FGOALS-f3-L r3i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# E3SM-1-1-ECA r1i1p1f1
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# UKESM1-0-LL r1i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# UKESM1-0-LL r2i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# UKESM1-0-LL r3i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# UKESM1-0-LL r8i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)
# UKESM1-0-LL r4i1p1f2
# (165, 72, 144)
# (86, 72, 144)
# (251, 72, 144)

# %% [markdown]
# # Save dictionary

# %%
# load pickle module
import pickle

# create a binary pickle file 
f = open("ssp585_time_series.pkl","wb")

# write the python object (dict) to pickle file
pickle.dump(dic_merged_runs_ssp585,f)

# close file
f.close()
